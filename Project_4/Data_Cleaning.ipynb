# %%
import pandas as pd

# %%
# Excel File to CSV
xlsx_file_path = './Resources/variables.xlsx'

df = pd.read_excel(xlsx_file_path, skiprows=7)

csv_file_path = 'variables.csv'

df.to_csv(csv_file_path, index=False)

# %%
Data_df = pd.read_csv("variables.csv")

# %% [markdown]
# # In order to avoid showing sensitive information we will drop some columns

# %%
columns_to_drop = ['ID de respuesta', 'Captura tu campo a dos dígitos. Ejemplo: 01','¿Cuál es tu número de tienda? Captúralo para que quede de 4 dígitos. Ejemplo: La tienda 18 sería 0018']
df_cleaner = Data_df.drop(columns=columns_to_drop)

# Display the modified DataFrame
df_cleaner.head()
# Out:
#   Bracket Nivel Socioeconómico  \
# 0     Mid                   C-
# 1     Top                   C-
# 2     Top                   C-
# 3     Top                    C
# 4     Mid                   C-
#
#   Si estas en esquina, que tipo de esquina es. ¿Esquina corta o larga? Considera lo siguiente  \
# 0                            Preferente / Far Corner
# 1                                Corta/ Short Corner
# 2                                Corta/ Short Corner
# 3                                Corta/ Short Corner
# 4                                Corta/ Short Corner
#
#   Si estas en esquina. ¿De qué lado te encuentras respecto al conductor de un automóvil? Manejando por la avenida con el flujo principal  \
# 0                                          Izquierda
# 1                                            Derecha
# 2                                            Derecha
# 3                                            Derecha
# 4                                            Derecha
#
# ...

# %%
csv_file_path = 'variables_clean.csv'

# %%
# Save the DataFrame to a CSV file
df_cleaner.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Next part of the data cleaning process will be made on the Google Colab Jupyter Notebook: "Project_4_Mercadia"
